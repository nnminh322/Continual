# %%
# Cell for start run
# !git clone -b main --single-branch --depth 1 https://github.com/nnminh322/Continual.git
# !pip install uv
# %cd Continual/root_gainlora/
# !bash setup_kaggle_colab.sh
# !bash gen_script_long_order3_t5_gainlora_inflora.sh 0 google/flan-t5-large
# Out:
# Cloning into 'Continual'...
# remote: Enumerating objects: 1185, done.
# remote: Counting objects: 100% (1185/1185), done.
# remote: Compressing objects: 100% (851/851), done.
# remote: Total 1185 (delta 271), reused 1164 (delta 267), pack-reused 0 (from 0)
# Receiving objects: 100% (1185/1185), 341.53 MiB | 30.39 MiB/s, done.
# Resolving deltas: 100% (271/271), done.
# Updating files: 100% (1684/1684), done.
# Collecting uv
#   Downloading uv-0.10.9-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.10.9-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 85.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: uv
# Successfully installed uv-0.10.9
# /content/Continual/root_gainlora
# ==========================================
# SpecRoute Setup for Kaggle/Colab
# ==========================================
# [Env] Detected: colab
# [Setup] Using current Python environment
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (75.2.0)
# Collecting setuptools
#   Downloading setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.46.3)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (26.0)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 31.7 MB/s eta 0:00:00a 0:00:01
# Downloading setuptools-82.0.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 71.9 MB/s eta 0:00:00
# Installing collected packages: setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed pip-26.0.1 setuptools-82.0.1
#
# [Remove] Uninstalling conflicting packages...
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# Found existing installation: triton 3.6.0
# Uninstalling triton-3.6.0:
#   Successfully uninstalled triton-3.6.0
# Found existing installation: cupy-cuda12x 14.0.1
# Uninstalling cupy-cuda12x-14.0.1:
#   Successfully uninstalled cupy-cuda12x-14.0.1
# Found existing installation: transformers 5.0.0
# Uninstalling transformers-5.0.0:
#   Successfully uninstalled transformers-5.0.0
# Found existing installation: tokenizers 0.22.2
# Uninstalling tokenizers-0.22.2:
#   Successfully uninstalled tokenizers-0.22.2
# Found existing installation: datasets 4.0.0
# Uninstalling datasets-4.0.0:
#   Successfully uninstalled datasets-4.0.0
# Found existing installation: accelerate 1.12.0
# Uninstalling accelerate-1.12.0:
#   Successfully uninstalled accelerate-1.12.0
# Found existing installation: peft 0.18.1
# Uninstalling peft-0.18.1:
#   Successfully uninstalled peft-0.18.1
# Found existing installation: sentence-transformers 5.2.3
# Uninstalling sentence-transformers-5.2.3:
#   Successfully uninstalled sentence-transformers-5.2.3
# Found existing installation: torchtune 0.6.1
# Uninstalling torchtune-0.6.1:
#   Successfully uninstalled torchtune-0.6.1
# Found existing installation: cudf-cu12 26.2.1
# Uninstalling cudf-cu12-26.2.1:
#   Successfully uninstalled cudf-cu12-26.2.1
# Found existing installation: dask-cudf-cu12 26.2.1
# Uninstalling dask-cudf-cu12-26.2.1:
#   Successfully uninstalled dask-cudf-cu12-26.2.1
# Found existing installation: cuml-cu12 26.2.0
# Uninstalling cuml-cu12-26.2.0:
#   Successfully uninstalled cuml-cu12-26.2.0
# Found existing installation: cucim-cu12 26.2.0
# Uninstalling cucim-cu12-26.2.0:
#   Successfully uninstalled cucim-cu12-26.2.0
# Found existing installation: ydf 0.15.0
# Uninstalling ydf-0.15.0:
#   Successfully uninstalled ydf-0.15.0
# Found existing installation: grain 0.2.16
# Uninstalling grain-0.2.16:
#   Successfully uninstalled grain-0.2.16
# Found existing installation: umap-learn 0.5.11
# Uninstalling umap-learn-0.5.11:
#   Successfully uninstalled umap-learn-0.5.11
# Found existing installation: hdbscan 0.8.41
# Uninstalling hdbscan-0.8.41:
#   Successfully uninstalled hdbscan-0.8.41
# Found existing installation: textblob 0.19.0
# Uninstalling textblob-0.19.0:
#   Successfully uninstalled textblob-0.19.0
# Found existing installation: opentelemetry-proto 1.38.0
# Uninstalling opentelemetry-proto-1.38.0:
#   Successfully uninstalled opentelemetry-proto-1.38.0
# Found existing installation: grpcio-status 1.71.2
# Uninstalling grpcio-status-1.71.2:
#   Successfully uninstalled grpcio-status-1.71.2
# Found existing installation: protobuf 5.29.6
# Uninstalling protobuf-5.29.6:
#   Successfully uninstalled protobuf-5.29.6
# Found existing installation: jax 0.7.2
# Uninstalling jax-0.7.2:
#   Successfully uninstalled jax-0.7.2
# Found existing installation: jaxlib 0.7.2
# Uninstalling jaxlib-0.7.2:
#   Successfully uninstalled jaxlib-0.7.2
# Found existing installation: fastai 2.8.7
# Uninstalling fastai-2.8.7:
#   Successfully uninstalled fastai-2.8.7
# Found existing installation: dopamine_rl 4.1.2
# Uninstalling dopamine_rl-4.1.2:
#   Successfully uninstalled dopamine_rl-4.1.2
# Found existing installation: flax 0.11.2
# Uninstalling flax-0.11.2:
#   Successfully uninstalled flax-0.11.2
# Found existing installation: optax 0.2.7
# Uninstalling optax-0.2.7:
#   Successfully uninstalled optax-0.2.7
# Found existing installation: orbax-checkpoint 0.11.33
# Uninstalling orbax-checkpoint-0.11.33:
#   Successfully uninstalled orbax-checkpoint-0.11.33
# Found existing installation: nx-cugraph-cu12 26.2.0
# Uninstalling nx-cugraph-cu12-26.2.0:
#   Successfully uninstalled nx-cugraph-cu12-26.2.0
# Found existing installation: pylibcugraph-cu12 26.2.0
# Uninstalling pylibcugraph-cu12-26.2.0:
#   Successfully uninstalled pylibcugraph-cu12-26.2.0
# Found existing installation: opencv-contrib-python 4.13.0.92
# Uninstalling opencv-contrib-python-4.13.0.92:
#   Successfully uninstalled opencv-contrib-python-4.13.0.92
# Found existing installation: opencv-python 4.13.0.92
# Uninstalling opencv-python-4.13.0.92:
#   Successfully uninstalled opencv-python-4.13.0.92
# Found existing installation: opencv-python-headless 4.13.0.92
# Uninstalling opencv-python-headless-4.13.0.92:
#   Successfully uninstalled opencv-python-headless-4.13.0.92
# Found existing installation: shap 0.50.0
# Uninstalling shap-0.50.0:
#   Successfully uninstalled shap-0.50.0
# Found existing installation: rasterio 1.5.0
# Uninstalling rasterio-1.5.0:
#   Successfully uninstalled rasterio-1.5.0
# Found existing installation: tobler 0.13.0
# Uninstalling tobler-0.13.0:
#   Successfully uninstalled tobler-0.13.0
# Found existing installation: pytensor 2.38.0
# Uninstalling pytensor-2.38.0:
#   Successfully uninstalled pytensor-2.38.0
# Found existing installation: tensorflow_decision_forests 1.12.0
# Uninstalling tensorflow_decision_forests-1.12.0:
#   Successfully uninstalled tensorflow_decision_forests-1.12.0
# Found existing installation: bigframes 2.36.0
# Uninstalling bigframes-2.36.0:
#   Successfully uninstalled bigframes-2.36.0
# Found existing installation: google-adk 1.26.0
# Uninstalling google-adk-1.26.0:
#   Successfully uninstalled google-adk-1.26.0
# Found existing installation: gcsfs 2025.3.0
# Uninstalling gcsfs-2025.3.0:
#   Successfully uninstalled gcsfs-2025.3.0
#
# [Install] Core CUDA stack (PyTorch cu121)...
# [Check] torch version after install: 2.5.1+cu121
# [Install] Project dependencies...
# [Install] CuPy (with fallback for Python/CUDA compatibility)...
# [Cache] Clearing stale HuggingFace dataset module cache...
# [Cache] HF dataset module cache cleared
#
# [Check] Verifying installation...
# ✓ python 3.12.12
# ✓ torch 2.5.1+cu121
# ✓ cuda available: True
# ✓ gpu count: 1
#   - GPU 0: Tesla T4 (15.6 GB)
# ✓ transformers 4.40.2
# ✓ datasets 2.21.0
# ✓ cupy 13.6.0
#
# [Success] All packages installed correctly!
#
# ==========================================
# [Ready] Environment is ready to use
# ==========================================
# bash: gen_script_superni_order1_t5_specroute.sh: No such file or directory

# %%
# Cell for remove run
# %cd /content
# !rm -rf ./Continual
# Out:
# NO LIBRARY ERRORS - only OOM (hardware constraint on T4 GPU)

# %%
# Cell for rerun
# %cd /content
# !rm -rf ./Continual
# !git clone -b main --single-branch --depth 1 https://github.com/nnminh322/Continual.git
# %cd /content/Continual/root_gainlora/
# !bash gen_script_long_order3_t5_gainlora_inflora.sh 0 google/flan-t5-large
# Out:
# /content
# Cloning into 'Continual'...
# remote: Enumerating objects: 358, done.
# remote: Counting objects: 100% (358/358), done.
# remote: Compressing objects: 100% (241/241), done.
# remote: Total 358 (delta 116), reused 335 (delta 108), pack-reused 0 (from 0)
# Receiving objects: 100% (358/358), 28.34 MiB | 10.69 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# Updating files: 100% (913/913), done.
# /content/Continual/root_gainlora
# 2026-03-12 02:41:40.290210: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773283300.510735    4868 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773283300.565349    4868 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773283300.963561    4868 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773283300.963609    4868 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773283300.963614    4868 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773283300.963616    4868 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-12 02:41:41.003056: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# 03/12/2026 02:41:47 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# Generating train split: 5000 examples [00:00, 21274.64 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yelp/train.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating validation split: 7600 examples [00:00, 21790.56 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yelp/dev.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating test split: 7600 examples [00:00, 21362.64 examples/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# [WARNING|modeling_utils.py:4172] 2026-03-12 02:42:36,740 >> Some weights of T5ForConditionalGeneration were not initialized from the model checkpoint at google/flan-t5-large and are newly initialized: ['decoder.block.0.layer.0.SelfAttention.lora_q.lora_A', 'decoder.block.0.layer.0.SelfAttention.lora_q.lora_B', 'decoder.block.0.layer.0.SelfAttention.lora_v.lora_A', 'decoder.block.0.layer.0.SelfAttention.lora_v.lora_B', 'decoder.block.0.layer.1.EncDecAttention.lora_q.lora_A', 'decoder.block.0.layer.1.EncDecAttention.lora_q.lora_B', 'decoder.block.0.layer.1.EncDecAttention.lora_v.lora_A', 'decoder.block.0.layer.1.EncDecAttention.lora_v.lora_B', 'decoder.block.1.layer.0.SelfAttention.lora_q.lora_A', 'decoder.block.1.layer.0.SelfAttention.lora_q.lora_B', 'decoder.block.1.layer.0.SelfAttention.lora_v.lora_A', 'decoder.block.1.layer.0.SelfAttention.lora_v.lora_B', 'decoder.block.1.layer.1.EncDecAttention.lora_q.lora_A', 'decoder.block.1.layer.1.EncDecAttention.lora_q.lora_B', 'decoder.block.1.layer.1.EncDecAttention.lora_v.lora_A', 'decoder.block.1.layer.1.EncDecAttention.lora_v.lora_B', 'decoder.block.10.layer.0.SelfAttention.lora_q.lora_A', 'decoder.block.10.layer.0.SelfAttention.lora_q.lora_B', 'decoder.block.10.layer.0.SelfAttention.lora_v.lora_A', 'decoder.block.10.layer.0.SelfAttention.lora_v.lora_B', 'decoder.block.10.layer.1.EncDecAttention.lora_q.lora_A', 'decoder.block.10.layer.1.EncDecAttention.lora_q.lora_B', 'decoder.block.10.layer.1.EncDecAttention.lora_v.lora_A', 'decoder.block.10.layer.1.EncDecAttention.lora_v.lora_B', 'decoder.block.11.layer.0.SelfAttention.lora_q.lora_A', 'decoder.block.11.layer.0.SelfAttention.lora_q.lora_B', 'decoder.block.11.layer.0.SelfAttention.lora_v.lora_A', 'decoder.block.11.layer.0.SelfAttention.lora_v.lora_B', 'decoder.block.11.layer.1.EncDecAttention.lora_q.lora_A', 'decoder.block.11.layer.1.EncDecAttention.lora_q.lora_B', 'decoder.block.11.layer.1.EncDecAttention.lora_v.lora_A', 'decoder.block.11.layer.1.EncDecAttention.lora_v.lora_B', 'decoder.block.12.layer.0.SelfAttention.lora_q.lora_A', 'decoder.block.12.layer.0.SelfAttention.lora_q.lora_B', 'decoder.block.12.layer.0.SelfAttention.lora_v.lora_A', 'decoder.block.12.layer.0.SelfAttention.lora_v.lora_B', 'decoder.block.12.layer.1.EncDecAttention.lora_q.lora_A', 'decoder.block.12.layer.1.EncDecAttention.lora_q.lora_B', 'decoder.block.12.layer.1.EncDecAttention.lora_v.lora_A', 'decoder.block.12.layer.1.EncDecAttention.lora_v.lora_B', 'decoder.block.13.layer.0.SelfAttention.lora_q.lora_A', 'decoder.block.13.layer.0.SelfAttention.lora_q.lora_B', 'decoder.block.13.layer.0.SelfAttention.lora_v.lora_A', 'decoder.block.13.layer.0.SelfAttention.lora_v.lora_B', 'decoder.block.13.layer.1.EncDecAttention.lora_q.lora_A', 'decoder.block.13.layer.1.EncDecAttention.lora_q.lora_B', 'decoder.block.13.layer.1.EncDecAttention.lora_v.lora_A', 'decoder.block.13.layer.1.EncDecAttention.lora_v.lora_B', 'decoder.block.14.layer.0.SelfAttention.lora_q.lora_A', 'decoder.block.14.layer.0.SelfAttention.lora_q.lora_B', 'decoder.block.14.layer.0.SelfAttention.lora_v.lora_A', 'decoder.block.14.layer.0.SelfAttention.lora_v.lora_B', 'decoder.block.14.layer.1.EncDecAttention.lora_q.lora_A', 'decoder.block.14.layer.1.EncDecAttention.lora_q.lora_B', 'decoder.block.14.layer.1.EncDecAttention.lora_v.lora_A', 'decoder.block.14.layer.1.EncDecAttention.lora_v.lora_B', 'decoder.block.15.layer.0.SelfAttention.lora_q.lora_A', 'decoder.block.15.layer.0.SelfAttention.lora_q.lora_B', 'decoder.block.15.layer.0.SelfAttention.lora_v.lora_A', 'decoder.block.15.layer.0.SelfAttention.lora_v.lora_B', 'decoder.block.15.layer.1.EncDecAttention.lora_q.lora_A', 'decoder.block.15.layer.1.EncDecAttention.lora_q.lora_B', 'decoder.block.15.layer.1.EncDecAttention.lora_v.lora_A', 'decoder.block.15.layer.1.EncDecAttention.lora_v.lora_B', 'decoder.block.16.layer.0.SelfAttention.lora_q.lora_A', 'decoder.block.16.layer.0.SelfAttention.lora_q.lora_B', 'decoder.block.16.layer.0.SelfAttention.lora_v.lora_A' ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [WARNING|tokenization_utils_base.py:3896] 2026-03-12 02:42:39,269 >> Token indices sequence length is longer than the specified maximum sequence length for this model (1242 > 512). Running this sequence through the model will result in indexing errors
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:3921: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yelp/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# encoder.prompt_key
# encoder.block.0.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.0.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.1.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.1.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.2.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.2.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.3.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.3.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.4.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.4.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.5.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.5.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.6.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.6.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.7.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.7.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.8.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.8.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.9.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.9.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.10.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.10.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.11.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.11.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.12.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.12.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.13.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.13.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.14.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.14.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.15.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.15.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.16.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.16.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.17.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.17.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.18.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.18.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.19.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.19.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.20.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.20.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.21.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.21.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.22.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.22.layer.0.SelfAttention.lora_v.lora_B
# encoder.block.23.layer.0.SelfAttention.lora_q.lora_B
# encoder.block.23.layer.0.SelfAttention.lora_v.lora_B
# encoder.trans_input.0.weight
# encoder.trans_input.2.weight
# decoder.block.0.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.0.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.0.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.0.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.1.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.1.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.1.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.1.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.2.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.2.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.2.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.2.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.3.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.3.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.3.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.3.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.4.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.4.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.4.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.4.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.5.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.5.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.5.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.5.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.6.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.6.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.6.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.6.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.7.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.7.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.7.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.7.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.8.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.8.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.8.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.8.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.9.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.9.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.9.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.9.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.10.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.10.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.10.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.10.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.11.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.11.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.11.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.11.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.12.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.12.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.12.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.12.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.13.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.13.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.13.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.13.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.14.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.14.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.14.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.14.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.15.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.15.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.15.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.15.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.16.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.16.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.16.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.16.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.17.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.17.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.17.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.17.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.18.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.18.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.18.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.18.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.19.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.19.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.19.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.19.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.20.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.20.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.20.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.20.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.21.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.21.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.21.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.21.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.22.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.22.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.22.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.22.layer.1.EncDecAttention.lora_v.lora_B
# decoder.block.23.layer.0.SelfAttention.lora_q.lora_B
# decoder.block.23.layer.0.SelfAttention.lora_v.lora_B
# decoder.block.23.layer.1.EncDecAttention.lora_q.lora_B
# decoder.block.23.layer.1.EncDecAttention.lora_v.lora_B
# Total number of parameters: 1.385M, rate: 0.18%
# -----Gradient checkpointing: False -----
# logs_and_outputs/gen_script_long_order3_t5_gainlora_inflora/outputs
# begin get representation
# end get representation
# is_deepspeed_enabled False
# Using Same Learning Rate for All Modules
#   0%|          | 0/1560 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 923, in <module>
#     main()
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 814, in main
#     train_result = trainer.train(resume_from_checkpoint=checkpoint)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/trainer.py", line 1859, in train
#     return inner_training_loop(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/cl_trainer_gainlora_inflora.py", line 1290, in _inner_training_loop
#     tr_loss_step = self.training_step(model, inputs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/cl_trainer_gainlora_inflora.py", line 538, in training_step
#     loss = self.compute_loss(model, inputs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/trainer.py", line 3161, in compute_loss
#     outputs = model(**inputs)
#               ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 2069, in forward
#     encoder_outputs = self.encoder(
#                       ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1449, in forward
#     layer_outputs = layer_module(
#                     ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 857, in forward
#     self_attention_outputs = self.layer[0](
#                              ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 760, in forward
#     attention_output = self.SelfAttention(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 689, in forward
#     scores = torch.matmul(
#              ^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 114.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 109.81 MiB is free. Including non-PyTorch memory, this process has 14.45 GiB memory in use. Of the allocated memory 14.14 GiB is allocated by PyTorch, and 156.04 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#   0%|          | 0/1560 [00:01<?, ?it/s]
# 2026-03-12 02:53:40.881260: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773284020.901595    7846 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773284020.907966    7846 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773284020.924376    7846 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284020.924418    7846 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284020.924422    7846 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284020.924424    7846 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-12 02:53:40.929663: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# 03/12/2026 02:53:47 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# Generating train split: 5000 examples [00:00, 19797.84 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/amazon/train.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating validation split: 7600 examples [00:00, 21575.14 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/amazon/dev.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating test split: 15200 examples [00:00, 21033.17 examples/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /content/Continual/root_gainlora/src/t5_gainlora_inflora.py:1080: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yelp/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/amazon/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# ----------Loading Previous Keys----------
# Traceback (most recent call last):
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 923, in <module>
#     main()
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 477, in main
#     model = T5ForConditionalGeneration.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 3550, in from_pretrained
#     model = cls(config, *model_args, **model_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1907, in __init__
#     self.encoder = T5Stack(encoder_config, self.shared, prompt_config)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1080, in __init__
#     self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1319, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 659, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 640, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'logs_and_outputs/gen_script_long_order3_t5_gainlora_inflora/outputs/1-yelp/saved_weights/prompts_keys_till_now.pt'
# 2026-03-12 02:54:00.269102: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773284040.288434    7947 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773284040.294646    7947 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773284040.310546    7947 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284040.310591    7947 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284040.310595    7947 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284040.310598    7947 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-12 02:54:00.315153: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# 03/12/2026 02:54:05 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# Generating train split: 3000 examples [00:00, 20030.04 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/mnli/train.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating validation split: 7600 examples [00:00, 15437.01 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/mnli/dev.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating test split: 22800 examples [00:01, 12383.68 examples/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /content/Continual/root_gainlora/src/t5_gainlora_inflora.py:1080: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yelp/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/amazon/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/mnli/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# ----------Loading Previous Keys----------
# Traceback (most recent call last):
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 923, in <module>
#     main()
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 477, in main
#     model = T5ForConditionalGeneration.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 3550, in from_pretrained
#     model = cls(config, *model_args, **model_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1907, in __init__
#     self.encoder = T5Stack(encoder_config, self.shared, prompt_config)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1080, in __init__
#     self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1319, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 659, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 640, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'logs_and_outputs/gen_script_long_order3_t5_gainlora_inflora/outputs/2-amazon/saved_weights/prompts_keys_till_now.pt'
# 2026-03-12 02:54:19.197447: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773284059.230988    8037 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773284059.241422    8037 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773284059.265258    8037 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284059.265314    8037 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284059.265331    8037 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284059.265345    8037 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-12 02:54:19.272276: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# 03/12/2026 02:54:24 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# Generating train split: 250 examples [00:00, 13378.28 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/cb/train.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating validation split: 56 examples [00:00, 8234.51 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/cb/dev.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating test split: 22856 examples [00:01, 22405.55 examples/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /content/Continual/root_gainlora/src/t5_gainlora_inflora.py:1080: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yelp/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/amazon/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/mnli/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/cb/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# ----------Loading Previous Keys----------
# Traceback (most recent call last):
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 923, in <module>
#     main()
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 477, in main
#     model = T5ForConditionalGeneration.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 3550, in from_pretrained
#     model = cls(config, *model_args, **model_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1907, in __init__
#     self.encoder = T5Stack(encoder_config, self.shared, prompt_config)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1080, in __init__
#     self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1319, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 659, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 640, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'logs_and_outputs/gen_script_long_order3_t5_gainlora_inflora/outputs/3-mnli/saved_weights/prompts_keys_till_now.pt'
# 2026-03-12 02:54:36.664446: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773284076.683861    8130 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773284076.689914    8130 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773284076.704673    8130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284076.704716    8130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284076.704720    8130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284076.704722    8130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-12 02:54:36.709264: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# 03/12/2026 02:54:41 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# Generating train split: 400 examples [00:00, 14478.72 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/copa/train.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating validation split: 100 examples [00:00, 8265.29 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/copa/dev.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating test split: 22956 examples [00:01, 12440.78 examples/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /content/Continual/root_gainlora/src/t5_gainlora_inflora.py:1080: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yelp/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/amazon/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/mnli/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/cb/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/copa/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# ----------Loading Previous Keys----------
# Traceback (most recent call last):
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 923, in <module>
#     main()
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 477, in main
#     model = T5ForConditionalGeneration.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 3550, in from_pretrained
#     model = cls(config, *model_args, **model_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1907, in __init__
#     self.encoder = T5Stack(encoder_config, self.shared, prompt_config)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1080, in __init__
#     self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1319, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 659, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 640, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'logs_and_outputs/gen_script_long_order3_t5_gainlora_inflora/outputs/4-cb/saved_weights/prompts_keys_till_now.pt'
# 2026-03-12 02:54:56.458343: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773284096.478209    8224 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773284096.484210    8224 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773284096.499096    8224 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284096.499139    8224 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284096.499151    8224 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284096.499154    8224 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-12 02:54:56.503514: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# 03/12/2026 02:55:01 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# Generating train split: 2000 examples [00:00, 21705.55 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/qqp/train.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating validation split: 7600 examples [00:00, 23303.99 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/qqp/dev.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating test split: 30556 examples [00:01, 21844.30 examples/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...
# 2026-03-12 02:57:34.898572: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773284254.920072    9018 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773284254.926374    9018 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773284254.941760    9018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284254.941807    9018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284254.941810    9018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284254.941812    9018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-12 02:57:34.946424: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# 03/12/2026 02:57:39 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# Generating train split: 2000 examples [00:00, 17109.87 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/boolq/train.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating validation split: 3270 examples [00:00, 19089.83 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/boolq/dev.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating test split: 70223 examples [00:03, 18199.44 examples/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /content/Continual/root_gainlora/src/t5_gainlora_inflora.py:1080: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yelp/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/amazon/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/mnli/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/cb/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/copa/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/qqp/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/rte/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/imdb/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/sst2/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/dbpedia/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/agnews/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yahoo/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/multirc/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/boolq/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# ----------Loading Previous Keys----------
# Traceback (most recent call last):
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 923, in <module>
#     main()
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 477, in main
#     model = T5ForConditionalGeneration.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 3550, in from_pretrained
#     model = cls(config, *model_args, **model_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1907, in __init__
#     self.encoder = T5Stack(encoder_config, self.shared, prompt_config)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1080, in __init__
#     self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1319, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 659, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 640, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'logs_and_outputs/gen_script_long_order3_t5_gainlora_inflora/outputs/13-multirc/saved_weights/prompts_keys_till_now.pt'
# 2026-03-12 02:57:55.463349: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773284275.496995    9120 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773284275.506665    9120 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773284275.530199    9120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284275.530238    9120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284275.530241    9120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773284275.530243    9120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-12 02:57:55.537882: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# 03/12/2026 02:58:01 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# Generating train split: 2000 examples [00:00, 16950.28 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/wic/train.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating validation split: 638 examples [00:00, 22792.61 examples/s]
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/wic/dev.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# Generating test split: 70861 examples [00:03, 20224.89 examples/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /content/Continual/root_gainlora/src/t5_gainlora_inflora.py:1080: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yelp/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/amazon/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/mnli/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/cb/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/copa/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/qqp/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/rte/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/imdb/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/sst2/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/dbpedia/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/agnews/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/yahoo/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/multirc/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/boolq/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# /content/Continual/root_gainlora/CL_Benchmark/Long_Sequence/wic/test.json
# ['Definition', 'Positive Examples', 'Negative Examples', 'Instances']
# ----------Loading Previous Keys----------
# Traceback (most recent call last):
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 923, in <module>
#     main()
#   File "/content/Continual/root_gainlora/src/run_t5.py", line 477, in main
#     model = T5ForConditionalGeneration.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 3550, in from_pretrained
#     model = cls(config, *model_args, **model_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1907, in __init__
#     self.encoder = T5Stack(encoder_config, self.shared, prompt_config)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Continual/root_gainlora/src/t5_gainlora_inflora.py", line 1080, in __init__
#     self.previous_prompts_keys.data = torch.load(prompt_config["previous_prompt_key_path"])
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1319, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 659, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 640, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'logs_and_outputs/gen_script_long_order3_t5_gainlora_inflora/outputs/14-boolq/saved_weights/prompts_keys_till_now.pt'
# Traceback (most recent call last):
#   File "/content/Continual/root_gainlora/score.py", line 42, in <module>
#     with open(f"logs_and_outputs/{run_name}/outputs/task_order.txt", 'r') as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'logs_and_outputs/gen_script_long_order3_t5_gainlora_inflora/outputs/task_order.txt'
# EXIT_CODE=0

# %%
# !bash setup_kaggle_colab.sh
# Out:
# ==========================================
# SpecRoute Setup for Kaggle/Colab
# ==========================================
# [Env] Detected: colab
# [Setup] Using current Python environment
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (75.2.0)
# Collecting setuptools
#   Downloading setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.46.3)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (26.0)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 78.7 MB/s eta 0:00:00
# Downloading setuptools-82.0.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 74.4 MB/s eta 0:00:00
# Installing collected packages: setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed pip-26.0.1 setuptools-82.0.1
#
# [Remove] Uninstalling conflicting packages...
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# Found existing installation: triton 3.6.0
# Uninstalling triton-3.6.0:
#   Successfully uninstalled triton-3.6.0
# Found existing installation: cupy-cuda12x 14.0.1
# Uninstalling cupy-cuda12x-14.0.1:
#   Successfully uninstalled cupy-cuda12x-14.0.1
# Found existing installation: transformers 5.0.0
# Uninstalling transformers-5.0.0:
#   Successfully uninstalled transformers-5.0.0
# Found existing installation: tokenizers 0.22.2
# Uninstalling tokenizers-0.22.2:
#   Successfully uninstalled tokenizers-0.22.2
# Found existing installation: datasets 4.0.0
# Uninstalling datasets-4.0.0:
#   Successfully uninstalled datasets-4.0.0
# Found existing installation: accelerate 1.13.0
# Uninstalling accelerate-1.13.0:
#   Successfully uninstalled accelerate-1.13.0
# Found existing installation: peft 0.18.1
# Uninstalling peft-0.18.1:
#   Successfully uninstalled peft-0.18.1
# Found existing installation: sentence-transformers 5.2.3
# Uninstalling sentence-transformers-5.2.3:
#   Successfully uninstalled sentence-transformers-5.2.3
# Found existing installation: torchtune 0.6.1
# Uninstalling torchtune-0.6.1:
#   Successfully uninstalled torchtune-0.6.1
# Found existing installation: cudf-cu12 26.2.1
# Uninstalling cudf-cu12-26.2.1:
#   Successfully uninstalled cudf-cu12-26.2.1
# Found existing installation: dask-cudf-cu12 26.2.1
# Uninstalling dask-cudf-cu12-26.2.1:
#   Successfully uninstalled dask-cudf-cu12-26.2.1
# Found existing installation: cuml-cu12 26.2.0
# Uninstalling cuml-cu12-26.2.0:
#   Successfully uninstalled cuml-cu12-26.2.0
# Found existing installation: cucim-cu12 26.2.0
# Uninstalling cucim-cu12-26.2.0:
#   Successfully uninstalled cucim-cu12-26.2.0
# Found existing installation: ydf 0.15.0
# Uninstalling ydf-0.15.0:
#   Successfully uninstalled ydf-0.15.0
# Found existing installation: grain 0.2.16
# Uninstalling grain-0.2.16:
#   Successfully uninstalled grain-0.2.16
# Found existing installation: umap-learn 0.5.11
# Uninstalling umap-learn-0.5.11:
#   Successfully uninstalled umap-learn-0.5.11
# Found existing installation: hdbscan 0.8.41
# Uninstalling hdbscan-0.8.41:
#   Successfully uninstalled hdbscan-0.8.41
# Found existing installation: textblob 0.19.0
# Uninstalling textblob-0.19.0:
#   Successfully uninstalled textblob-0.19.0
# Found existing installation: opentelemetry-proto 1.38.0
# Uninstalling opentelemetry-proto-1.38.0:
#   Successfully uninstalled opentelemetry-proto-1.38.0
# Found existing installation: grpcio-status 1.71.2
# Uninstalling grpcio-status-1.71.2:
#   Successfully uninstalled grpcio-status-1.71.2
# Found existing installation: protobuf 5.29.6
# Uninstalling protobuf-5.29.6:
#   Successfully uninstalled protobuf-5.29.6
# Found existing installation: jax 0.7.2
# Uninstalling jax-0.7.2:
#   Successfully uninstalled jax-0.7.2
# Found existing installation: jaxlib 0.7.2
# Uninstalling jaxlib-0.7.2:
#   Successfully uninstalled jaxlib-0.7.2
# Found existing installation: fastai 2.8.7
# Uninstalling fastai-2.8.7:
#   Successfully uninstalled fastai-2.8.7
# Found existing installation: dopamine_rl 4.1.2
# Uninstalling dopamine_rl-4.1.2:
#   Successfully uninstalled dopamine_rl-4.1.2
# Found existing installation: flax 0.11.2
# Uninstalling flax-0.11.2:
#   Successfully uninstalled flax-0.11.2
# Found existing installation: optax 0.2.7
# Uninstalling optax-0.2.7:
#   Successfully uninstalled optax-0.2.7
# Found existing installation: orbax-checkpoint 0.11.33
# Uninstalling orbax-checkpoint-0.11.33:
#   Successfully uninstalled orbax-checkpoint-0.11.33
# Found existing installation: nx-cugraph-cu12 26.2.0
# Uninstalling nx-cugraph-cu12-26.2.0:
#   Successfully uninstalled nx-cugraph-cu12-26.2.0
# Found existing installation: pylibcugraph-cu12 26.2.0
# Uninstalling pylibcugraph-cu12-26.2.0:
#   Successfully uninstalled pylibcugraph-cu12-26.2.0
# Found existing installation: opencv-contrib-python 4.13.0.92
# Uninstalling opencv-contrib-python-4.13.0.92:
#   Successfully uninstalled opencv-contrib-python-4.13.0.92
# Found existing installation: opencv-python 4.13.0.92
# Uninstalling opencv-python-4.13.0.92:
#   Successfully uninstalled opencv-python-4.13.0.92
# Found existing installation: opencv-python-headless 4.13.0.92
# Uninstalling opencv-python-headless-4.13.0.92:
#   Successfully uninstalled opencv-python-headless-4.13.0.92
# Found existing installation: shap 0.51.0
# Uninstalling shap-0.51.0:
#   Successfully uninstalled shap-0.51.0
# Found existing installation: rasterio 1.5.0
# Uninstalling rasterio-1.5.0:
#   Successfully uninstalled rasterio-1.5.0
# Found existing installation: tobler 0.13.0
# Uninstalling tobler-0.13.0:
#   Successfully uninstalled tobler-0.13.0
# Found existing installation: pytensor 2.38.1
# Uninstalling pytensor-2.38.1:
#   Successfully uninstalled pytensor-2.38.1
# Found existing installation: tensorflow_decision_forests 1.12.0
# Uninstalling tensorflow_decision_forests-1.12.0:
#   Successfully uninstalled tensorflow_decision_forests-1.12.0
# Found existing installation: bigframes 2.37.0
# Uninstalling bigframes-2.37.0:
#   Successfully uninstalled bigframes-2.37.0
# Found existing installation: google-adk 1.26.0
# Uninstalling google-adk-1.26.0:
#   Successfully uninstalled google-adk-1.26.0
# Found existing installation: gcsfs 2025.3.0
# Uninstalling gcsfs-2025.3.0:
#   Successfully uninstalled gcsfs-2025.3.0
#
# [Install] Core CUDA stack (PyTorch cu121)...
# [Check] torch version after install: 2.5.1+cu121
# [Install] Project dependencies...
# [Install] CuPy (with fallback for Python/CUDA compatibility)...
# [Cache] Clearing stale HuggingFace dataset module cache...
# [Cache] HF dataset module cache cleared
#
# [Check] Verifying installation...
# ✓ python 3.12.12
# ✓ torch 2.5.1+cu121
# ✓ cuda available: True
# ✓ gpu count: 1
#   - GPU 0: Tesla T4 (15.6 GB)
# ✓ transformers 4.40.2
# ✓ datasets 2.21.0
# ✓ cupy 13.6.0
#
# [Success] All packages installed correctly!
#
# ==========================================
# [Ready] Environment is ready to use
# ==========================================
