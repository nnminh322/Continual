# %%
# Cell for start run
# !git clone -b main --single-branch --depth 1 https://github.com/nnminh322/Continual.git
# !pip install uv
# %cd Continual/root_gainlora/
# !bash setup_kaggle_colab.sh
# !bash gen_script_superni_order1_t5_specroute.sh 0 google/flan-t5-large

# %%
# Cell for remove run
# %cd ../..
# !rm -rf ./Continual

# %%
# Cell for rerun
# !git clone -b main --single-branch --depth 1 https://github.com/nnminh322/Continual.git
# %cd Continual/root_gainlora/
# !bash gen_script_superni_order1_t5_specroute.sh 0 google/flan-t5-large
