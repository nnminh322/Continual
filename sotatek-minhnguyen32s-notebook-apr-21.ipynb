# %% [markdown]
# # Welcome to Modal notebooks!
#
# Write Python code and collaborate in real time. Your code runs in Modal's
# **serverless cloud**, and anyone in the same workspace can join.
#
# This notebook comes with some common Python libraries installed. Run
# cells with `Shift+Enter`.

# %%
# !git clone -b llama https://github.com/nnminh322/Continual
# %cd Continual/new_gainlora
# !bash setup_server.sh
# Out:
# Cloning into 'Continual'...
# remote: Enumerating objects: 4805, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 4805 (delta 33), reused 30 (delta 14), pack-reused 4753 (from 3)
# Receiving objects: 100% (4805/4805), 505.52 MiB | 55.83 MiB/s, done.
# Resolving deltas: 100% (2950/2950), done.
# Updating files: 100% (1544/1544), done.
# /root/Continual/new_gainlora
# ...
# SpecRoute Setup for GPU Server (RTX 5090)
# ...
# [GPU] NVIDIA L40S
# [Python] 3.12
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 111.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.45.1
#     Uninstalling wheel-0.45.1:
#       Successfully uninstalled wheel-0.45.1
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# ...
#
# [1/7] Uninstalling old CUDA packages...
# ...

# %%
# !pip install --upgrade typer huggingface_hub
# Out:
# ...
#   Attempting uninstall: typer
#     Found existing installation: typer 0.17.3
#     Uninstalling typer-0.17.3:
#       Successfully uninstalled typer-0.17.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [typer]
# ...

# %%
# !hf auth login --token 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
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `hf`CLI if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# The token `abcabc` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `abcabc`

# %%
# !pip uninstall cupy -y
# !pip install cupy-cuda12x
# Out:
# WARNING: Skipping cupy as it is not installed.
# ...
#   Attempting uninstall: cuda-pathfinder
#     Found existing installation: cuda-pathfinder 1.2.2
#     Uninstalling cuda-pathfinder-1.2.2:
#       Successfully uninstalled cuda-pathfinder-1.2.2
# ...

# %%
# !bash gen_script_superni_order1_llama_srt.sh meta-llama/Llama-2-7b-hf
# Out:
# ...
# [CONFIG] sgwi=True, dual_fisher=False, lambda_emb=auto
# ...
# [GPU] mid_bf16 (46068 MB) | CUDA_VISIBLE_DEVICES=0 | meta-llama/Llama-2-7b-hf
# ...
# [SRT] use_srt_router=True, sgwi=True, dual_fisher=False, srt_skip_forward=True
# 04/21/2026 09:05:33 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, fp16: False, bf16: True
# DatasetDict({
#     train: Dataset({
#         features: ['Task', 'Dataset', 'subset', 'Samples', 'Instance'],
#         num_rows: 160
#     })
#     validation: Dataset({
#         features: ['Task', 'Dataset', 'subset', 'Samples', 'Instance'],
#         num_rows: 20
#     })
#     test: Dataset({
#         features: ['Task', 'Dataset', 'subset', 'Samples', 'Instance'],
#         num_rows: 20
#     })
# })
# ...

# %%
# !git pull origin llama
# !rm -rf logs_and_outputs
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 6 (delta 5), reused 6 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 766 bytes | 95.00 KiB/s, done.
# From https://github.com/nnminh322/Continual
#  * branch            llama      -> FETCH_HEAD
#    a8049c8..1ad127b  llama      -> origin/llama
# Updating a8049c8..1ad127b
# Fast-forward
#  new_gainlora/src/cl_trainer_gainlora_llama.py | 19 ++++++++++++++++---
#  new_gainlora/src/llama_gainlora.py            |  4 +++-
#  2 files changed, 19 insertions(+), 4 deletions(-)
